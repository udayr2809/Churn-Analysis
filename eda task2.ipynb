# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Importing Dataset

# %%
client =pd.read_csv("client_data (1).csv")

# %%
price =pd.read_csv("price_data (1).csv")

# %% [markdown]
# ### Exploring Datasets

# %%
client.head()
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
price.head()
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
# 3  038af19179925da21a25619c5a24b745  2015-04-01            0.149626
# 4  038af19179925da21a25619c5a24b745  2015-05-01            0.149626
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
# 3             0.0                 0.0           44.266931             0.0
# 4             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0
# ...

# %%
print("Total NULL valuesin the client dataset :", client.isnull().sum())
print("Total NULL valuesin the price dataset :", price.isnull().sum())
# Out:
# Total NULL valuesin the client dataset : id                                0
# channel_sales                     0
# cons_12m                          0
# cons_gas_12m                      0
# cons_last_month                   0
# date_activ                        0
# date_end                          0
# date_modif_prod                   0
# date_renewal                      0
# forecast_cons_12m                 0
# forecast_cons_year                0
# forecast_discount_energy          0
# forecast_meter_rent_12m           0
# forecast_price_energy_off_peak    0
# forecast_price_energy_peak        0
# forecast_price_pow_off_peak       0
# has_gas                           0
# imp_cons                          0
# margin_gross_pow_ele              0
# margin_net_pow_ele                0
# nb_prod_act                       0
# net_margin                        0
# num_years_antig                   0
# origin_up                         0
# pow_max                           0
# ...

# %%
print("shape of client dataset :",client.shape)
print("shape of price dataset :",price.shape)
# Out:
# shape of client dataset : (14606, 26)
# shape of price dataset : (193002, 8)

# %%
print("columns of client dataset :",client.columns)
print("columns of price dataset :",price.columns)
# Out:
# columns of client dataset : Index(['id', 'channel_sales', 'cons_12m', 'cons_gas_12m', 'cons_last_month',
#        'date_activ', 'date_end', 'date_modif_prod', 'date_renewal',
#        'forecast_cons_12m', 'forecast_cons_year', 'forecast_discount_energy',
#        'forecast_meter_rent_12m', 'forecast_price_energy_off_peak',
#        'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'has_gas',
#        'imp_cons', 'margin_gross_pow_ele', 'margin_net_pow_ele', 'nb_prod_act',
#        'net_margin', 'num_years_antig', 'origin_up', 'pow_max', 'churn'],
#       dtype='object')
# columns of price dataset : Index(['id', 'price_date', 'price_off_peak_var', 'price_peak_var',
#        'price_mid_peak_var', 'price_off_peak_fix', 'price_peak_fix',
#        'price_mid_peak_fix'],
#       dtype='object')

# %% [markdown]
# ### Datatype of columns

# %%
print("Datatype of columns of client dataset :")
client.dtypes
# Out:
# Datatype of columns of client dataset :
# id                                 object
# channel_sales                      object
# cons_12m                            int64
# cons_gas_12m                        int64
# cons_last_month                     int64
# date_activ                         object
# date_end                           object
# date_modif_prod                    object
# date_renewal                       object
# forecast_cons_12m                 float64
# forecast_cons_year                  int64
# forecast_discount_energy          float64
# forecast_meter_rent_12m           float64
# forecast_price_energy_off_peak    float64
# forecast_price_energy_peak        float64
# forecast_price_pow_off_peak       float64
# has_gas                            object
# imp_cons                          float64
# margin_gross_pow_ele              float64
# margin_net_pow_ele                float64
# nb_prod_act                         int64
# ...

# %%
print("Datatype of columns of price dataset :")
price.dtypes
# Out:
# Datatype of columns of price dataset :
# id                     object
# price_date             object
# price_off_peak_var    float64
# price_peak_var        float64
# price_mid_peak_var    float64
# price_off_peak_fix    float64
# price_peak_fix        float64
# price_mid_peak_fix    float64
# dtype: object

# %% [markdown]
# ### Descriptive Statistics

# %%
print("Description of client dataset :")
client.describe().T
# Out:
# Description of client dataset :
#                                   count           mean            std  min  \
# cons_12m                        14606.0  159220.286252  573465.264198  0.0
# cons_gas_12m                    14606.0   28092.375325  162973.059057  0.0
# cons_last_month                 14606.0   16090.269752   64364.196422  0.0
# forecast_cons_12m               14606.0    1868.614880    2387.571531  0.0
# forecast_cons_year              14606.0    1399.762906    3247.786255  0.0
# forecast_discount_energy        14606.0       0.966726       5.108289  0.0
# forecast_meter_rent_12m         14606.0      63.086871      66.165783  0.0
# forecast_price_energy_off_peak  14606.0       0.137283       0.024623  0.0
# forecast_price_energy_peak      14606.0       0.050491       0.049037  0.0
# forecast_price_pow_off_peak     14606.0      43.130056       4.485988  0.0
# imp_cons                        14606.0     152.786896     341.369366  0.0
# ...

# %%
print("Description of price dataset :")
price.describe().T
# Out:
# Description of price dataset :
#                        count       mean        std  min        25%        50%  \
# price_off_peak_var  193002.0   0.141027   0.025032  0.0   0.125976   0.146033
# price_peak_var      193002.0   0.054630   0.049924  0.0   0.000000   0.085483
# price_mid_peak_var  193002.0   0.030496   0.036298  0.0   0.000000   0.000000
# price_off_peak_fix  193002.0  43.334477   5.410297  0.0  40.728885  44.266930
# price_peak_fix      193002.0  10.622875  12.841895  0.0   0.000000   0.000000
# price_mid_peak_fix  193002.0   6.409984   7.773592  0.0   0.000000   0.000000
#
#                           75%        max
# price_off_peak_var   0.151635   0.280700
# price_peak_var       0.101673   0.229788
# price_mid_peak_var   0.072558   0.114102
# price_off_peak_fix  44.444710  59.444710
# price_peak_fix      24.339581  36.490692
# price_mid_peak_fix  16.226389  17.458221

# %%
print("Unique values in client dataset")
for i in client.columns:
    print("{} : {}".format(i,client[i].nunique()))
# Out:
# Unique values in client dataset
# id : 14606
# channel_sales : 8
# cons_12m : 11065
# cons_gas_12m : 2112
# cons_last_month : 4751
# date_activ : 1796
# date_end : 368
# date_modif_prod : 2129
# date_renewal : 386
# forecast_cons_12m : 13993
# forecast_cons_year : 4218
# forecast_discount_energy : 12
# forecast_meter_rent_12m : 3528
# forecast_price_energy_off_peak : 516
# forecast_price_energy_peak : 329
# forecast_price_pow_off_peak : 41
# has_gas : 2
# imp_cons : 7752
# margin_gross_pow_ele : 2391
# margin_net_pow_ele : 2391
# nb_prod_act : 10
# net_margin : 11965
# num_years_antig : 13
# origin_up : 6
# pow_max : 698
# churn : 2

# %%
print("Unique values in price dataset")
for i in price.columns:
    print("{} : {}".format(i,price[i].nunique()))
# Out:
# Unique values in price dataset
# id : 16096
# price_date : 12
# price_off_peak_var : 1853
# price_peak_var : 1189
# price_mid_peak_var : 711
# price_off_peak_fix : 66
# price_peak_fix : 31
# price_mid_peak_fix : 28

# %% [markdown]
# ### Separating Numeric and Categorical column

# %%
pricenumcol=[]
pricecatcol=[]
for col in price.columns:
    if price[col].dtype=='o' or price[col].dtype=='object':
        pricecatcol.append(col)
    else:
        pricenumcol.append(col)

# %%
pricecatcol
# Out:
# ['id', 'price_date']

# %%
pricenumcol
# Out:
# ['price_off_peak_var',
#  'price_peak_var',
#  'price_mid_peak_var',
#  'price_off_peak_fix',
#  'price_peak_fix',
#  'price_mid_peak_fix']

# %%
clientnumcol=[]
clientcatcol=[]
for col in client.columns:
    if client[col].dtype=='o' or client[col].dtype=='object':
        clientcatcol.append(col)
    else:
        clientnumcol.append(col)

# %%
clientcatcol
# Out:
# ['id',
#  'channel_sales',
#  'date_activ',
#  'date_end',
#  'date_modif_prod',
#  'date_renewal',
#  'has_gas',
#  'origin_up']

# %%
clientnumcol
# Out:
# ['cons_12m',
#  'cons_gas_12m',
#  'cons_last_month',
#  'forecast_cons_12m',
#  'forecast_cons_year',
#  'forecast_discount_energy',
#  'forecast_meter_rent_12m',
#  'forecast_price_energy_off_peak',
#  'forecast_price_energy_peak',
#  'forecast_price_pow_off_peak',
#  'imp_cons',
#  'margin_gross_pow_ele',
#  'margin_net_pow_ele',
#  'nb_prod_act',
#  'net_margin',
#  'num_years_antig',
#  'pow_max',
#  'churn']

# %% [markdown]
# ### Visualizing Distributions of columns

# %% [markdown]
# #### Client Dataset

# %%
for i in clientnumcol:
    plot = sns.displot(client[i], kde=True, height=4, aspect=2)
    plot.set(title="Distribution of {} in data".format(i))
    plt.xlabel(i)
    plt.ylabel('Frequency')

# %% [markdown]
# #### Price Dataset

# %%
for i in pricenumcol:
    plot = sns.displot(price[i], kde=True, height=4, aspect=2)
    plot.set(title="Distribution of {} in data".format(i))
    plt.xlabel(i)
    plt.ylabel('Frequency')

# %% [markdown]
# #### Categorical Column Distribution

# %%
# Distribution of channel sales

# %%
data = client['channel_sales'].value_counts()
labels=client['channel_sales'].unique()

# %%
plt.figure(figsize=(4, 4))
plt.pie(data, labels=labels)
plt.title('Distribution of Channel Sales')
# Out:
# Text(0.5, 1.0, 'Distribution of Channel Sales')

# %%
# Distribution gas client

# %%
data = client['has_gas'].value_counts()
labels=client['has_gas'].unique()
plt.figure(figsize=(4, 4))
plt.pie(data, labels=labels)
plt.title('Distribution of Gas Client')
# Out:
# Text(0.5, 1.0, 'Distribution of Gas Client')

# %%
#Distribution of client churned over the next 3 months

# %%
data = client['churn'].value_counts()
labels=client['churn'].unique()
plt.figure(figsize=(4, 4))
plt.pie(data, labels=labels)
plt.title('Distribution of client churned over the next 3 months')
# Out:
# Text(0.5, 1.0, 'Distribution of client churned over the next 3 months')
